# %% [markdown]
# # Diary Movies

# %% [markdown]
# ## Genres

# %%
import pandas as pd

df = pd.read_csv('diary_movies_with_genres.csv')

df['genre'].str.split(', ').explode().value_counts()
# Out:
# genre
# Drama              31
# Romance            14
# Crime              13
# Comedy              8
# Animation           8
# Family              6
# Fantasy             6
# Thriller            6
# Mystery             5
# Adventure           3
# Music               2
# Action              2
# History             2
# Western             2
# Science Fiction     1
# Horror              1
# Documentary         1
# War                 1
# Name: count, dtype: int64
